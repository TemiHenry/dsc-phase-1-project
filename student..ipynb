# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Temitope henry Ajayi
# * Student pace: part time
# * Scheduled project review date/time: 22nd Mar 2024
# * Instructor name: RAJIVE ISLAM
# * Github URL: https://github.com/TemiHenry/dsc-phase-1-project.git

# %% [markdown]
# Project Overview
# For this project, you will use exploratory data analysis to generate insights for a business stakeholder.
#
# Business Problem
# Microsoft wants to get in on the excitement after noticing that all the major corporations are producing original video content. They don't know nothing about making movies, yet they have decided to start a new studio.
# It is your responsibility to research the kinds of movies that are at present performing the best at the box office. The next step is to convert those results into practical advice that the president of Microsoft's new film company may use to choose the kind of movies that should be made.

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Load the dataset into Jupyter notebook 
Movie_Gross = pd.read_csv("C:/Users/Tolu/Downloads/Project/dsc-phase-1-project-/zippedData/bom.movie_gross.csv.gz")
Movie_Gross.sample(100)
# Out:
#                                     title   studio  domestic_gross  \
# 574                       The Trip (2011)      IFC       2000000.0
# 293               Around a Small Mountain     CGld         33200.0
# 3103                   Fifty Shades Freed     Uni.     100400000.0
# 3130  The House With A Clock In Its Walls     Uni.      68500000.0
# 1787                     The Green Prince     MBox        258000.0
# ...                                   ...      ...             ...
# 29                              True Grit     Par.     171200000.0
# 569                  Oranges and Sunshine    Cohen        143000.0
# 2824               The LEGO Ninjago Movie       WB      59300000.0
# 3041                Extraordinary Mission  Crimson         54200.0
# 2789                  Annabelle: Creation  WB (NL)     102100000.0
#
#      foreign_gross  year
# 574            NaN  2011
# 293         131000  2010
# 3103     271500000  2018
# 3130      62900000  2018
# 1787           NaN  2014
# ...

# %%
#calculating average missing values in each column
percent_missing = Movie_Gross.isnull().sum() * 100 / len(Gross)
print(percent_missing)
# Out:
# title              0.000000
# studio             0.147623
# domestic_gross     0.826690
# foreign_gross     39.858282
# year               0.000000
# dtype: float64

# %%
#indentifying the  data types of each column
Movie_Gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#replace each null value in foreign gross column to a numerical value 0
Movie_Gross['foreign_gross'].replace(np.nan,0,inplace=True)
Movie_Gross.isna().sum()
# Out:
# title              0
# studio             5
# domestic_gross    28
# foreign_gross      0
# year               0
# dtype: int64

# %%
#replace each null value in domestic gross column to a numerical value 0
Movie_Gross['domestic_gross'].replace(np.nan,0,inplace=True)
Movie_Gross.isna().sum()
# Out:
# title             0
# studio            5
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
#confirms total missing values
Movie_Gross.isna().sum()
# Out:
# title             0
# studio            5
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
percent_missing = Movie_Gross.isnull().sum() * 100 / len(Gross)
print(percent_missing)
# Out:
# title             0.000000
# studio            0.147623
# domestic_gross    0.000000
# foreign_gross     0.000000
# year              0.000000
# dtype: float64

# %%
# # combines foreign _gross and domestic_to create a new column with total gross value
# import pandas as pd
Movie_Gross = pd.read_csv("C:/Users/Tolu/Downloads/Project/dsc-phase-1-project-/zippedData/bom.movie_gross.csv.gz")
Movie_Gross = pd.DataFrame(Movie_Gross)
Movie_Gross['foreign_gross'] = Movie_Gross['foreign_gross'].str.replace(',', '').astype(float)
Movie_Gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
Movie_Gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
Movie_Gross['foreign_gross'].replace(np.nan, 0, inplace = True, regex = False)
Movie_Gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
# # combines foreign _gross and domestic_to create a new column with total gross value
Movie_Gross['Total gross'] = Movie_Gross['domestic_gross'] + Movie_Gross['foreign_gross']
Movie_Gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
Movie_Gross['domestic_gross']
# Out:
# 0       415000000.0
# 1       334200000.0
# 2       296000000.0
# 3       292600000.0
# 4       238700000.0
#            ...
# 3382         6200.0
# 3383         4800.0
# 3384         2500.0
# 3385         2400.0
# 3386         1700.0
# Name: domestic_gross, Length: 3387, dtype: float64

# %%
#loads second table basics
Title_Basic = pd.read_csv("C:/Users/Tolu/Downloads/Project/dsc-phase-1-project-/zippedData/imdb.title.basics.csv.gz")
Title_Basic.head(10)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
# 7  tt0137204                  Joe Finds Grace             Joe Finds Grace
# 8  tt0139613                       O Silêncio                  O Silêncio
# 9  tt0144449            Nema aviona za Zagreb       Nema aviona za Zagreb
#
#    start_year  runtime_minutes                      genres
# 0        2013            175.0          Action,Crime,Drama
# ...

# %%
#checks for the data types
Title_Basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# Remove original _ title,(similar to primary title)
Title_Basic = pd.read_csv("C:/Users/Tolu/Downloads/Project/dsc-phase-1-project-/zippedData/imdb.title.basics.csv.gz")
Title_Basic = pd.DataFrame(Title_Basic)
Title_Basic.drop(['original_title'],axis=1, inplace=True)
Title_Basic
# Out:
#            tconst                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# ...

# %%
#loads 3rd table ratings
Title_Rating= pd.read_csv("C:/Users/Tolu/Downloads/Project/dsc-phase-1-project-/zippedData/imdb.title.ratings.csv.gz")
Title_Rating.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#checks data types and null values
Title_Rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
Title_Rating.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
#drop numvotes(assupmtion data was used to calculate average rating)
Title_Rating = pd.read_csv("C:/Users/Tolu/Downloads/Project/dsc-phase-1-project-/zippedData/imdb.title.ratings.csv.gz")
Title_Rating = pd.DataFrame(Title_Rating)
Title_Rating.drop(['numvotes'],axis=1, inplace=True)
Title_Rating
# Out:
#            tconst  averagerating
# 0      tt10356526            8.3
# 1      tt10384606            8.9
# 2       tt1042974            6.4
# 3       tt1043726            4.2
# 4       tt1060240            6.5
# ...           ...            ...
# 73851   tt9805820            8.1
# 73852   tt9844256            7.5
# 73853   tt9851050            4.7
# 73854   tt9886934            7.0
# 73855   tt9894098            6.3
#
# [73856 rows x 2 columns]

# %%
#Merge Basic and Ratings
#renames primary title to allow merge with Gross dataframe, replaces start_year with year
Basic_and_Ratings = pd.merge(Title_Basic,Title_Rating)
Basic_and_Ratings.rename(columns = {'primary_title':'title','start_year':'year'}, inplace = True)
Basic_and_Ratings
# Out:
#           tconst                            title  year  runtime_minutes  \
# 0      tt0063540                        Sunghursh  2013            175.0
# 1      tt0066787  One Day Before the Rainy Season  2019            114.0
# 2      tt0069049       The Other Side of the Wind  2018            122.0
# 3      tt0069204                  Sabse Bada Sukh  2018              NaN
# 4      tt0100275         The Wandering Soap Opera  2017             80.0
# ...          ...                              ...   ...              ...
# 73851  tt9913084                 Diabolik sono io  2019             75.0
# 73852  tt9914286                Sokagin Çocuklari  2019             98.0
# 73853  tt9914642                        Albatross  2017              NaN
# 73854  tt9914942       La vida sense la Sara Amat  2019              NaN
# 73855  tt9916160                       Drømmeland  2019             72.0
#
#                      genres  averagerating
# 0        Action,Crime,Drama            7.0
# ...

# %%
#checks for data types
Basic_and_Ratings.dtypes
# Out:
# tconst              object
# title               object
# year                 int64
# runtime_minutes    float64
# genres              object
# averagerating      float64
# dtype: object

# %%
Basic_and_Ratings.isna().sum()
# Out:
# tconst                0
# title                 0
# year                  0
# runtime_minutes    7620
# genres              804
# averagerating         0
# dtype: int64

# %%
#combines the three tables, Basic, Rating  and Gross
Movie_Gross_Basic_and_Ratings = pd.merge(Movie_Gross,Basic_and_Ratings)
Movie_Gross_Basic_and_Ratings
# Out:
#                            title studio  domestic_gross  foreign_gross  year  \
# 0                    Toy Story 3     BV     415000000.0    652000000.0  2010
# 1                      Inception     WB     292600000.0    535700000.0  2010
# 2            Shrek Forever After   P/DW     238700000.0    513900000.0  2010
# 3     The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# 4                     Iron Man 2   Par.     312400000.0    311500000.0  2010
# ...                          ...    ...             ...            ...   ...
# 1842             Helicopter Eela   Eros         72000.0            0.0  2018
# 1843          Girls vs Gangsters  WGUSA         37100.0            0.0  2018
# 1844           A Paris Education     KL         21600.0            0.0  2018
# 1845                   The Quake  Magn.          6200.0            0.0  2018
# 1846           An Actor Prepares  Grav.          1700.0            0.0  2018
#
# ...

# %%
Movie_Gross_Basic_and_Ratings.isna().sum()
# Out:
# title               0
# studio              2
# domestic_gross     10
# foreign_gross       0
# year                0
# Total gross        10
# tconst              0
# runtime_minutes     4
# genres              2
# averagerating       0
# dtype: int64

# %%
#Delete tconst column
Movie_Gross_Basic_and_Ratings.drop(['tconst'],axis=1, inplace=True)
Movie_Gross_Basic_and_Ratings
# Out:
#                            title studio  domestic_gross  foreign_gross  year  \
# 0                    Toy Story 3     BV     415000000.0    652000000.0  2010
# 1                      Inception     WB     292600000.0    535700000.0  2010
# 2            Shrek Forever After   P/DW     238700000.0    513900000.0  2010
# 3     The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# 4                     Iron Man 2   Par.     312400000.0    311500000.0  2010
# ...                          ...    ...             ...            ...   ...
# 1842             Helicopter Eela   Eros         72000.0            0.0  2018
# 1843          Girls vs Gangsters  WGUSA         37100.0            0.0  2018
# 1844           A Paris Education     KL         21600.0            0.0  2018
# 1845                   The Quake  Magn.          6200.0            0.0  2018
# 1846           An Actor Prepares  Grav.          1700.0            0.0  2018
#
# ...

# %%
Movie_Gross_Basic_and_Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847 entries, 0 to 1846
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1847 non-null   object
#  1   studio           1845 non-null   object
#  2   domestic_gross   1837 non-null   float64
#  3   foreign_gross    1847 non-null   float64
#  4   year             1847 non-null   int64
#  5   Total gross      1837 non-null   float64
#  6   runtime_minutes  1843 non-null   float64
#  7   genres           1845 non-null   object
#  8   averagerating    1847 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 130.0+ KB

# %%
#calculates the total missing values in the data set
missing_values = Movie_Gross_Basic_and_Ratings.isna().sum() 
missing_values
# Out:
# title               0
# studio              2
# domestic_gross     10
# foreign_gross       0
# year                0
# Total gross        10
# runtime_minutes     4
# genres              2
# averagerating       0
# dtype: int64

# %%
#Calculated the missing data in %age
percent_missing = Movie_Gross_Basic_and_Ratings.isnull().sum() * 100 / len(Movie_Gross_Basic_and_Ratings)
print(percent_missing)
# Out:
# title              0.000000
# studio             0.108284
# domestic_gross     0.541419
# foreign_gross      0.000000
# year               0.000000
# Total gross        0.541419
# runtime_minutes    0.216567
# genres             0.108284
# averagerating      0.000000
# dtype: float64

# %%
#check and remove duplicates
print(Movie_Gross_Basic_and_Ratings.duplicated(['title']).sum())
# Out:
# 25

# %%
Movie_Gross_Basic_and_Ratings.drop_duplicates(subset=None,keep='first',inplace=True)
print(Movie_Gross_Basic_and_Ratings.duplicated(['title']).sum())
# Out:
# 25

# %%
print(Movie_Gross_Basic_and_Ratings.duplicated(['title']))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1842    False
# 1843    False
# 1844    False
# 1845    False
# 1846    False
# Length: 1847, dtype: bool

# %%
# drop nan rows under genres column
Movie_Gross_Basic_and_Ratings.dropna(subset=['genres'], inplace=True)
Movie_Gross_Basic_and_Ratings
# Out:
#                            title studio  domestic_gross  foreign_gross  year  \
# 0                    Toy Story 3     BV     415000000.0    652000000.0  2010
# 1                      Inception     WB     292600000.0    535700000.0  2010
# 2            Shrek Forever After   P/DW     238700000.0    513900000.0  2010
# 3     The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# 4                     Iron Man 2   Par.     312400000.0    311500000.0  2010
# ...                          ...    ...             ...            ...   ...
# 1842             Helicopter Eela   Eros         72000.0            0.0  2018
# 1843          Girls vs Gangsters  WGUSA         37100.0            0.0  2018
# 1844           A Paris Education     KL         21600.0            0.0  2018
# 1845                   The Quake  Magn.          6200.0            0.0  2018
# 1846           An Actor Prepares  Grav.          1700.0            0.0  2018
#
# ...

# %%
#cleans genre column where a movie fits in more than 1 genre, first is picked the rest are dropped
Movie_Gross_Basic_and_Ratings['genres'] = Movie_Gross_Basic_and_Ratings['genres'].str.split(',').str[0]
Movie_Gross_Basic_and_Ratings
# Out:
#                            title studio  domestic_gross  foreign_gross  year  \
# 0                    Toy Story 3     BV     415000000.0    652000000.0  2010
# 1                      Inception     WB     292600000.0    535700000.0  2010
# 2            Shrek Forever After   P/DW     238700000.0    513900000.0  2010
# 3     The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# 4                     Iron Man 2   Par.     312400000.0    311500000.0  2010
# ...                          ...    ...             ...            ...   ...
# 1842             Helicopter Eela   Eros         72000.0            0.0  2018
# 1843          Girls vs Gangsters  WGUSA         37100.0            0.0  2018
# 1844           A Paris Education     KL         21600.0            0.0  2018
# 1845                   The Quake  Magn.          6200.0            0.0  2018
# 1846           An Actor Prepares  Grav.          1700.0            0.0  2018
#
# ...

# %%
Movie_Gross_Basic_and_Ratings['genres'].value_counts()
# Out:
# genres
# Action         523
# Comedy         397
# Drama          329
# Adventure      166
# Biography      166
# Crime           80
# Documentary     70
# Horror          68
# Animation       17
# Fantasy          9
# Romance          7
# Thriller         6
# Mystery          5
# Music            1
# Sci-Fi           1
# Name: count, dtype: int64

# %%
#group the data by the 'genres' column and calculate the average rating for each genre using groupby and mean to make the plot more readable
genre_avg_rating = Movie_Gross_Basic_and_Ratings.groupby('genres')['averagerating'].mean().sort_values()

# Plot the bar chart
plt.figure(figsize=(10,6))
genre_avg_rating.plot(kind='pie')
plt.title('Average Rating by Genre')
#plt.xlabel('Genre')
#plt.ylabel('Average Rating')
plt.show()

# %%
Movie_Gross_Basic_and_Ratings['Total gross']
# Out:
# 0       1.067000e+09
# 1       8.283000e+08
# 2       7.526000e+08
# 3       6.985000e+08
# 4       6.239000e+08
#             ...
# 1842    7.200000e+04
# 1843    3.710000e+04
# 1844    2.160000e+04
# 1845    6.200000e+03
# 1846    1.700000e+03
# Name: Total gross, Length: 1845, dtype: float64

# %%
#group the data by the 'genres' column and calculate the total gross for each genre using groupby and sum for aesier readability.
plt.figure(figsize=(10,6))
sns.barplot(x='genres', y='Total gross', data=Movie_Gross_Basic_and_Ratings, errorbar=None)
plt.title('Total Gross by Genre')
plt.xticks(rotation=45)
plt.show()

# %%
#To visualize the relationship between genres, average ratings, and total gross,i used a scatter plot.
#Each point on the plot represents a movie, with the x-coordinate corresponding to its average rating, 
#the y-coordinate corresponding to its total gross, and the color indicating its genre.
plt.figure(figsize=(10,6))
sns.scatterplot(x='averagerating', y='Total gross', hue='genres', data=Movie_Gross_Basic_and_Ratings, alpha=0.7, palette='viridis')
plt.title('Relationship between Genres, Average Ratings, and Total Gross')
plt.xlabel('Average Rating')
plt.ylabel('Total Gross')
plt.show()

# %%
Category = Movie_Gross_Basic_and_Ratings.groupby(['genres'])['averagerating'].max().sort_values(ascending = False)
Category
# Out:
# genres
# Action         8.8
# Documentary    8.8
# Adventure      8.6
# Crime          8.5
# Drama          8.5
# Biography      8.3
# Fantasy        8.2
# Comedy         8.1
# Mystery        8.1
# Animation      7.8
# Horror         7.7
# Music          7.2
# Romance        7.1
# Thriller       6.8
# Sci-Fi         5.9
# Name: averagerating, dtype: float64

# %%
total_gross_weight = 0.6  
average_rating_weight = 0.4

# Calculate the profitability m
Movie_Gross_Basic_and_Ratings['profitability'] = (Movie_Gross_Basic_and_Ratings['Total gross'] * total_gross_weight) + (Movie_Gross_Basic_and_Ratings['averagerating'] * average_rating_weight)

# Group the data by genre and calculate the mean profitability for each genre
genre_profitability = Movie_Gross_Basic_and_Ratings.groupby('genres')['profitability'].mean().sort_values(ascending=False)
genre_profitability
# Out:
# genres
# Adventure      1.536868e+08
# Action         1.147279e+08
# Mystery        8.613396e+07
# Animation      8.001950e+07
# Horror         5.547578e+07
# Biography      3.268328e+07
# Comedy         3.156295e+07
# Drama          2.500379e+07
# Crime          2.431790e+07
# Romance        1.931597e+07
# Thriller       1.446750e+07
# Fantasy        9.466803e+06
# Documentary    7.429183e+06
# Music          4.800003e+06
# Sci-Fi         4.680236e+04
# Name: profitability, dtype: float64

# %%
#calculating the most profitable genre
# weight put on importance
total_gross_weight = 0.6 
average_rating_weight = 0.4

# Calculate the profitability m
Movie_Gross_Basic_and_Ratings['profitability'] = (Movie_Gross_Basic_and_Ratings['Total gross'] * total_gross_weight) + (Movie_Gross_Basic_and_Ratings['averagerating'] * average_rating_weight)

# Group the data by genre and calculate the mean profitability for each genre
genre_profitability = Movie_Gross_Basic_and_Ratings.groupby('genres')['profitability'].mean().sort_values(ascending=False)

# The genre with the highest average profitability is considered the most profitable
most_profitable_genre = genre_profitability.idxmax()
average_profitability_most_profitable_genre = genre_profitability.max()

print(f"The most profitable genre in relation to total gross and average rating is '{most_profitable_genre}' with an average profitability of {average_profitability_most_profitable_genre:.2f}.")
# Out:
# The most profitable genre in relation to total gross and average rating is 'Adventure' with an average profitability of 153686826.90.

# %% [markdown]
# Conclusion: Microsoft should consider Adventure genre in their new studio as it ratings and profit magine(total gross)
# offers the highest profitability of all available genres
